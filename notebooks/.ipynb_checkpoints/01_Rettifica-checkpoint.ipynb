# %% [markdown]
# # SIV Project: Board Game Analysis
# **Students:** Federico Berra and Davide Verzotto

# %% [markdown]
# ## Environment Setup & Tools
# In this section, we initialize the workspace by importing core libraries.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def display_image(image, title="Image View"):
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)
    plt.title(title)
    plt.axis('off')
    plt.show()


def get_rectified_view(image, src_pts, w, h):
    """
    Transforms the perspective of a 4-point selection into a flat rectangle.
    """
    dst_pts = np.float32([[0, 0], [w, 0], [w, h], [0, h]])
    M = cv2.getPerspectiveTransform(src_pts, dst_pts)
    return cv2.warpPerspective(image, M, (w, h))

print("Setup Complete. Tools are ready!")
# Out:
# Setup Complete. Tools are ready!

# %% [markdown]
# ## Perspective Transformation
# To accurately analyze the board, we must correct the perspective distortion caused by the camera angle.

# %%
image_path = '../imgs/pic9156909.png' 
raw_img = cv2.imread(image_path)

if raw_img is None:
    print(f"Error: '{image_path}' not found! Check if the file is inside the 'imgs' folder.")
else:
    print(f"Image '{image_path}' loaded successfully!")
    
    h, w = raw_img.shape[:2]
    src_pts = np.float32([
        [0, 0],       # Top-Left placeholder
        [w, 0],       # Top-Right placeholder
        [w, h],       # Bottom-Right placeholder
        [0, h]        # Bottom-Left placeholder
    ])

    rectified_img = get_rectified_view(raw_img, src_pts, 1000, 1400)

    display_image(raw_img, "Original Photo")
    display_image(rectified_img, "Rectified Result")
# Out:
# Image '../imgs/pic9156909.png' loaded successfully!
